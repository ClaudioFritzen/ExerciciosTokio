# %%
"""
1. Exercício

Criação

- Crie uma classe chamada Ponto com os atributos X e Y.

- Adicione um construtor que inicialize X e Y com valores padrão zero.

- Implemente o método str para exibir o ponto no formato (X,Y).

- Adicione um método quadrante para indicar a que quadrante pertence o ponto ou se
está na origem.

- Adicione um método vetor que recebe outro objeto ponto e calcula o vetor resultante
entre os dois objetos pontos.

"""
# Out:
# '\n1. Exercício\n\nCriação\n\n- Crie uma classe chamada Ponto com os atributos X e Y.\n\n- Adicione um construtor que inicialize X e Y com valores padrão zero.\n\n- Implemente o método str para exibir o ponto no formato (X,Y).\n\n- Adicione um método quadrante para indicar a que quadrante pertence o ponto ou se\nestá na origem.\n\n- Adicione um método vetor que recebe outro objeto ponto e calcula o vetor resultante\nentre os dois objetos pontos.\n\n'

# %%
"""
Experiência
- Criar os pontos A(2, 3), B(5,5), C(-3, -1) e D(0,0).
- Verifique a que quadrantes pertencem os pontos A, C e D.
- Calcule os vetores AB e BA e exiba os resultados.
"""
# Out:
# '\nExperiência\n- Criar os pontos A(2, 3), B(5,5), C(-3, -1) e D(0,0).\n- Verifique a que quadrantes pertencem os pontos A, C e D.\n- Calcule os vetores AB e BA e exiba os resultados.\n'

# %%
class Ponto:
    X = 0
    Y = 0

    def __init__(self, new_X, new_Y):
        self.X = new_X
        self.Y = new_Y

        print(f"Valores de X ({self.X}) and value Y ({self.Y})")

    def quadrante(self):

        if self.X == 0 and self.Y == 0:
            print(f"Está no quadrante inicial")
            return self.X, self.Y

        elif self.X > 0 and self.Y > 0:
            print(f"Você está no 1ª Quadrante!")

        elif self.X < 0 and self.Y > 0:
            print(f"Você está no 2ª Quadrante!")

        elif self.X < 0 and self.Y < 0:
            print(f"Você está no 3ª Quadrante!")

        elif self.X > 0 and self.Y < 0:
            print(f"Você está no 4ª Quadrante!")
        else:

            print("Bugou o sistema!")
    
    def __str__(self):

        return f"Ponto (X {self.X} e Y {self.Y})"
    
    def vetor(self, outro_ponto):
        return(outro_ponto.X - self.X, outro_ponto.Y - self.Y)

# %%
A = Ponto(2, 3)
A.quadrante()
print("\n")

B = Ponto(5, 5)
B.quadrante()
print("\n")

C = Ponto(-3, -1)
C.quadrante()
print("\n")

D = Ponto(0, 0)
D.quadrante()
print("\n")

E = Ponto(-4, 4)
E.quadrante()
print("\n")

F = Ponto(4, -4)
F.quadrante()
print("\n")

print(10 * "-", "__str()__")

print(str(A))
print(str(B))
print(str(C))
print(str(D))
print(str(E))
print(str(F))

print(10 * "-", "Diferença entre vetores!")

# aqui faremos A - B
diferença_vetor_A_pro_B = A.vetor(B)
diferença_vetor_B_pro_A = B.vetor(A)
print(f"Diferença entre os  Vetores entre A e B: {diferença_vetor_A_pro_B}")
print(f"Diferença entre os  Vetores entre B e A: {diferença_vetor_B_pro_A}")
# Out:
# Valores de X (2) and value Y (3)
# Você está no 1ª Quadrante!
#
#
# Valores de X (5) and value Y (5)
# Você está no 1ª Quadrante!
#
#
# Valores de X (-3) and value Y (-1)
# Você está no 3ª Quadrante!
#
#
# Valores de X (0) and value Y (0)
# Está no quadrante inicial
#
#
# Valores de X (-4) and value Y (4)
# Você está no 2ª Quadrante!
#
#
# Valores de X (4) and value Y (-4)
# Você está no 4ª Quadrante!
#
#
# ---------- __str()__
# Ponto (X 2 e Y 3)
# Ponto (X 5 e Y 5)
# Ponto (X -3 e Y -1)
# Ponto (X 0 e Y 0)
# Ponto (X -4 e Y 4)
# Ponto (X 4 e Y -4)
# ---------- Diferença entre vetores!
# Diferença entre os  Vetores entre A e B: (3, 2)
# Diferença entre os  Vetores entre B e A: (-3, -2)

# %%
"""
2. Exercício
Criação
- Crie uma classe chamada Retângulo com dois atributos do tipo Ponto (inicial e final) 
representando a diagonal do retângulo.
- Adicione um método construtor (init) que inicialize os atributos pontos.
- Adicione um método chamado base que calcula e retorna a base do retângulo.
- Adicione um método chamado altura que calcula e retorna a altura do retângulo.
- Adicione um método chamado área que calcula e retorna a área do retângulo.
Dicas:
- Use a função abs() para encontrar o valor absoluto.
- Para calcular a base e a altura, subtraia as coordenadas dos 
pontos.
- A área do retângulo é calculada multiplicando a base pela 
altura.
"""
# Out:
# '\n2. Exercício\nCriação\n- Crie uma classe chamada Retângulo com dois atributos do tipo Ponto (inicial e final) \nrepresentando a diagonal do retângulo.\n- Adicione um método construtor (init) que inicialize os atributos pontos.\n- Adicione um método chamado base que calcula e retorna a base do retângulo.\n- Adicione um método chamado altura que calcula e retorna a altura do retângulo.\n- Adicione um método chamado área que calcula e retorna a área do retângulo.\nDicas:\n- Use a função abs() para encontrar o valor absoluto.\n- Para calcular a base e a altura, subtraia as coordenadas dos \npontos.\n- A área do retângulo é calculada multiplicando a base pela \naltura.\n'

# %%
### refazendo o codigo

## para sabermos a area do retangulo é feita a base * altura

class Pontos:
    x = 0
    y = 0

    def __init__(self, new_x, new_y):

        self.x = new_x
        self.y = new_y
        

        print("OK")
    
    def __str__(self):
        return f"Ponto ({self.x},{self.y})"
    
class Retângulo:
    
    ponto_inicial = 0
    ponto_final = 0

    def __init__(self, new_ponto_inicial, new_ponto_final):

        self.ponto_inicial = new_ponto_inicial
        self.ponto_final = new_ponto_final

        print("Retângulo criado")
        
    def base(self):
        base = abs(self.ponto_final.x - self.ponto_inicial.x)
        return base

    def altura(self):
        altura = abs(self.ponto_final.y - self.ponto_inicial.y) 
        return altura

    def area(self):

        area = self.base() * self.altura()
        
        
        return area
    
    def __str__(self):
        return f"Retangulo(Ponto Inicial: {self.ponto_inicial}, Ponto Final: {self.ponto_final})"

# %%
# cire dois objetos Pontos A(2,3) e B(5,5) e os imprima
a = Pontos(2,3)
b = Pontos(5,5)

print(str(a))
print(str(b))

# crie um objeto retangulo utilizando os pontos a e b

retangulo = Retângulo(a,b)
print(retangulo)

# Consulte e imprima a base, altura e area do retangulo
print(f"Base: {retangulo.base()}")
print(f"Altura: {retangulo.altura()}")
print(f"Area: {retangulo.area()}")
# Out:
# OK
# OK
# Ponto (2,3)
# Ponto (5,5)
# Retângulo criado
# Retangulo(Ponto Inicial: Ponto (2,3), Ponto Final: Ponto (5,5))
# Base: 3
# Altura: 2
# Area: 6

# %%
"""
3. Exercício
Criação
- Crie uma classe chamada Veículo com os seguintes atributos: cor e rodas
- Adicione um construtor (init) para inicializar os atributos cor e rodas.
- Implemente o método (str) para retornar as informações do veículo.
- Crie uma classe Carro que herda de Veículo, e acrescente os seguintes atributos: velocidade e 
cilindrada.
- Adicione um construtor que inicializa os atributos velocidade e cilindrada, além dos herdados.
- Implemente o método (str) na classe Carro para retornar as informações do carro.
- Crie as seguintes classes herdadas de Veículo: Bicicleta, Moto, Camião
- Adicione construtores para essas classes que inicializem os atributos herdados.
- Crie uma classe chamada Concessionário

- Adicione um método chamada catalogar na classe Concessionario, que recebem um 
parâmetro: lista de veículos. Objetivo será para exibir o nome da classe e os atributos de cada 
veículo. Utilize a instrução type(objeto). __ name __ para obter o nome da classe.
- Adicione um método chamada filtrar na classe Concessionario, que recebe dois parâmetros: 
lista_veiculos e tipo_veiculo (tipos de veículos ex.: Carro, Camião). O objetivo será percorrer a 
lista  e  procurar  objetos  que  pertençam  ao  tipo  especificado  informado,  além  disso,  deve 
retornar uma nova lista com os veículos filtrados.

"""
# Out:
# '\n3. Exercício\nCriação\n- Crie uma classe chamada Veículo com os seguintes atributos: cor e rodas\n- Adicione um construtor (init) para inicializar os atributos cor e rodas.\n- Implemente o método (str) para retornar as informações do veículo.\n- Crie uma classe Carro que herda de Veículo, e acrescente os seguintes atributos: velocidade e \ncilindrada.\n- Adicione um construtor que inicializa os atributos velocidade e cilindrada, além dos herdados.\n- Implemente o método (str) na classe Carro para retornar as informações do carro.\n- Crie as seguintes classes herdadas de Veículo: Bicicleta, Moto, Camião\n- Adicione construtores para essas classes que inicializem os atributos herdados.\n- Crie uma classe chamada Concessionário\n\n- Adicione um método chamada catalogar na classe Concessionario, que recebem um \nparâmetro: lista de veículos. Objetivo será para exibir o nome da classe e os atributos de cada \nveículo. Utilize a instrução type(objeto). __ name __ para obter o nome da cl
# ...

# %%
class Veiculo:

    cor = ""
    rodas = 0

    def __init__(self, new_cor, new_rodas):

        self.cor = new_cor
        self.rodas = new_rodas

    
    def __str__(self):
        return f"Veiculo -> Cor: {self.cor} Qtd Rodas: {self.rodas}"


class Carro(Veiculo):

    def __init__(self, new_cor, new_rodas, velocidade, cilindrada):
        super().__init__(new_cor, new_rodas)

        self.velocidade = velocidade
        self.cilindrada = cilindrada
    
    def __str__(self):
        return f"Carro - Cor: {self.cor}, Qtd_Rodas: {self.rodas}, Velocidade MAX {self.velocidade} KM/H, Cilindrada: {self.cilindrada} cc"

class Bicicleta(Veiculo):
    def __init__(self, new_cor, new_rodas, tamanho):
        super().__init__(new_cor, new_rodas)
        self.tamanho = tamanho

    def __str__(self):
        return f"Bicicleta - Cor {self.cor}, Qtd_Rodas {self.rodas}, Tamanho: {self.tamanho}"


class Moto(Veiculo):
    def __init__(self, new_cor, new_rodas, tanque_capacidade, cc ):
        super().__init__(new_cor, new_rodas) 

        self.tanque_capacidade = int(tanque_capacidade)
        self.cc = int(cc)   

    def __str__(self):
        return f"Moto - Cor {self.cor}, Qtd_Rodas: {self.rodas}, Capacidade Max de Litros {self.tanque_capacidade} litros, Cilindradas: {self.cc} cc"

class Caminhao(Veiculo):

    def __init__(self, new_cor, new_rodas, toneladas):
        super().__init__(new_cor, new_rodas)

        self.toneladas = toneladas
    
    def __str__(self):
        return f"Caminhão - Cor: {self.cor}, Quantidade de Rodas: {self.rodas}, Capacidade Max: {self.toneladas} Toneladas"
    

class Concecionario:

    def __init__(self):

        self.lista = []

    def adicionar(self, veiculo):
        self.lista.append(veiculo)

    def mostrarLista(self):

        for veiculos in self.lista:
            print(f"{veiculos}")
    
    def catalogar(self, lista_veiculos):

        for veiculo in lista_veiculos:
            print(f"{type(veiculo).__name__}: {veiculo} ")

    def filtrar(self, lista_veiculos, tipo_veiculo):
        veiculos_filtrados = []
        for veiculo in lista_veiculos:
            if isinstance(veiculo, tipo_veiculo):
                veiculos_filtrados.append(veiculo)
            
        print("Veiculos Filtrados")
        for veiculo in veiculos_filtrados:
            print(veiculo)
        
        return veiculos_filtrados

veiculos = Veiculo("Azul", 78)

carro1 = Carro("Branco",5, 240, 90)
carro2 = Carro("Preto",3, 180, 60)
bicileta1 = Bicicleta("MTB ROXA", 2, "Adulto")
bicileta2 = Bicicleta("MTB Preta", 2, "Infantil")
moto1 = Moto("Preta", 2, "60", "99")
moto2 = Moto("Branca", 2, "100", "140")
caminhao1 = Caminhao("Vulvo Preto", 22, 150)
caminhao2 = Caminhao("Mercedes Marron", 22, 150)


print(str(veiculos))
print(str(carro1))
print(str(bicileta1))
print(str(moto1))
print(str(caminhao1))
print("--"*10)

concesionaria = Concecionario()

concesionaria.adicionar(carro1)
concesionaria.adicionar(carro2)
concesionaria.adicionar(bicileta1)
concesionaria.adicionar(bicileta2)
concesionaria.adicionar(moto1)
concesionaria.adicionar(moto2)
concesionaria.adicionar(caminhao1)
concesionaria.adicionar(caminhao2)

print("Mostrar lista veiculos")
concesionaria.mostrarLista()

print("\nCatalogar")
concesionaria.catalogar(concesionaria.lista)


veiculos_filtrados = concesionaria.filtrar(concesionaria.lista, Bicicleta)
# Out:
# Veiculo -> Cor: Azul Qtd Rodas: 78
# Carro - Cor: Branco, Qtd_Rodas: 5, Velocidade MAX 240 KM/H, Cilindrada: 90 cc
# Bicicleta - Cor MTB ROXA, Qtd_Rodas 2, Tamanho: Adulto
# Moto - Cor Preta, Qtd_Rodas: 2, Capacidade Max de Litros 60 litros, Cilindradas: 99 cc
# Caminhão - Cor: Vulvo Preto, Quantidade de Rodas: 22, Capacidade Max: 150 Toneladas
# --------------------
# Mostrar lista veiculos
# Carro - Cor: Branco, Qtd_Rodas: 5, Velocidade MAX 240 KM/H, Cilindrada: 90 cc
# Carro - Cor: Preto, Qtd_Rodas: 3, Velocidade MAX 180 KM/H, Cilindrada: 60 cc
# Bicicleta - Cor MTB ROXA, Qtd_Rodas 2, Tamanho: Adulto
# Bicicleta - Cor MTB Preta, Qtd_Rodas 2, Tamanho: Infantil
# Moto - Cor Preta, Qtd_Rodas: 2, Capacidade Max de Litros 60 litros, Cilindradas: 99 cc
# Moto - Cor Branca, Qtd_Rodas: 2, Capacidade Max de Litros 100 litros, Cilindradas: 140 cc
# Caminhão - Cor: Vulvo Preto, Quantidade de Rodas: 22, Capacidade Max: 150 Toneladas
# ...
